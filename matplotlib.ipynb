# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1. Generate some random data
data = np.random.randn(1000)

# 2. Create a histogram with 10 bins
hist, bins = np.histogram(data, bins=10)

print("Histogram Counts:", hist)
print("\nBin Edges:", bins)

# 3. Plot the histogram
plt.hist(data, bins=10)
plt.show()
# Out:
# Histogram Counts: [  8  27  72 166 212 224 175  80  29   7]
#
# Bin Edges: [-2.96814557 -2.36481449 -1.76148342 -1.15815235 -0.55482128  0.0485098
#   0.65184087  1.25517194  1.85850301  2.46183408  3.06516516]
